# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# step:-
# 0.Preprocess + EDA Feature selection
# 1.Extract input and output cots
# 2.Scale the value
# 3.Train the model
# 4.Evaluate the model selection
# 6.Deploy the model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
x.shape
# Out:
# (100, 2)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 47   5.2  161.0
# 54   6.4  141.0
# 34   4.8  163.0
# 8    6.1  156.0
# 20   6.6  120.0
# ..   ...    ...
# 87   5.7  132.0
# 52   7.0  175.0
# 56   6.1   65.0
# 82   6.5   37.0
# 95   4.3  200.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 47    0
# 54    1
# 34    0
# 8     0
# 20    1
#      ..
# 87    1
# 52    1
# 56    0
# 82    1
# 95    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 32   7.0  139.0
# 1    5.9  106.0
# 96   4.4   42.0
# 80   4.9  196.0
# 7    5.0   63.0
# 86   5.1  128.0
# 75   4.8  169.0
# 27   6.0  124.0
# 55   7.8  114.0
# 88   4.4  149.0

# %%
y_test
# Out:
# 32    1
# 1     0
# 96    0
# 80    0
# 7     0
# 86    0
# 75    0
# 27    1
# 55    1
# 88    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.74346032,  0.95046656],
#        [ 0.31582351,  0.44159095],
#        [-1.09655493,  1.00135412],
#        [ 0.05100255,  0.82324765],
#        [ 0.49237082, -0.09272844],
#        [-0.0372711 , -1.46669259],
#        [ 0.75719178,  0.3652596 ],
#        [-1.09655493, -0.29627869],
#        [ 0.22754986, -0.52527271],
#        [ 0.93373908,  0.69602875],
#        [-0.2138184 ,  0.46703473],
#        [-0.56691301, -0.24539113],
#        [ 0.84546543,  1.91733022],
#        [-1.09655493,  0.44159095],
#        [-1.80274415, -1.23769857],
#        [ 0.93373908, -1.92468064],
#        [ 1.11028639,  0.33981582],
#        [-0.30209206,  0.41614717],
#        [ 1.11028639, -0.95781698],
#        [ 0.13927621, -0.27083491],
#        [ 0.75719178, -0.70337918],
#        [ 1.28683369,  0.16170936],
#        [ 0.66891812, -0.85604186],
#        [ 0.49237082,  0.3652596 ],
#        [-1.27310224,  0.56880985],
#        [ 1.37510735, -0.88148564],
#        [ 0.66891812, -0.0163971 ],
#        [ 0.58064447,  0.77236009],
#        [-1.18482858, -1.82290552],
#        [ 0.05100255,  0.21259692],
#        [-0.83173397, -1.46669259],
#        [-1.00828128, -0.09272844],
#        [-0.92000763, -0.14361601],
#        [ 2.16957022, -0.09272844],
#        [-1.18482858, -0.9323732 ],
#        [-0.74346032,  0.21259692],
#        [ 1.81647561,  0.64514119],
#        [-0.30209206,  0.49247851],
#        [ 0.05100255, -0.52527271],
#        [ 1.37510735,  0.1108218 ],
#        [ 0.40409717, -0.85604186],
#        [-0.2138184 ,  1.07768546],
#        [-0.65518667, -0.06728466],
#        [-1.89101781, -0.37261003],
#        [-0.74346032,  2.55342473],
#        [ 1.28683369, -1.5939115 ],
#        [ 0.05100255, -1.08503589],
#        [-0.83173397,  1.33212326],
#        [ 0.40409717,  0.92502278],
#        [ 0.58064447,  1.48478595],
#        [-1.00828128,  0.26348448],
#        [-0.30209206,  1.1540168 ],
#        [ 0.84546543, -1.51758015],
#        [-0.0372711 , -2.00101198],
#        [-1.00828128, -1.5939115 ],
#        [ 0.84546543, -0.29627869],
#        [-0.56691301,  0.28892826],
#        [ 1.72820196, -1.13592345],
#        [-0.74346032, -0.34716625],
#        [ 0.40409717,  0.16170936],
#        [ 1.99302292,  1.12857302],
#        [-0.0372711 ,  0.64514119],
#        [-0.92000763, -0.83059808],
#        [-1.00828128,  0.69602875],
#        [-0.74346032, -0.85604186],
#        [-2.24411242,  2.78241875],
#        [ 0.66891812,  0.44159095],
#        [-1.00828128,  0.79780387],
#        [-2.42065972,  1.51022973],
#        [ 0.31582351, -0.19450357],
#        [ 1.81647561,  1.07768546],
#        [ 1.28683369,  0.87413522],
#        [-0.56691301,  0.39070339],
#        [ 0.66891812, -0.29627869],
#        [ 1.19856004,  0.21259692],
#        [-1.80274415, -0.60160406],
#        [ 1.11028639, -0.19450357],
#        [ 1.11028639, -1.87379308],
#        [ 0.75719178,  0.39070339],
#        [-0.65518667, -0.24539113],
#        [-0.0372711 , -0.55071649],
#        [-1.18482858, -0.06728466],
#        [ 0.22754986,  0.1108218 ],
#        [-0.56691301, -0.42349759],
#        [ 0.22754986,  0.08537802],
#        [-0.30209206,  0.21259692],
#        [ 0.84546543,  1.30667948],
#        [ 0.05100255, -1.49213637],
#        [ 0.40409717, -2.20456223],
#        [-1.5379232 ,  1.942774  ]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.84546543,  0.39070339],
#        [-0.12554475, -0.44894137],
#        [-1.44964954, -2.07734333],
#        [-1.00828128,  1.84099888],
#        [-0.92000763, -1.54302393],
#        [-0.83173397,  0.1108218 ],
#        [-1.09655493,  1.1540168 ],
#        [-0.0372711 ,  0.00904668],
#        [ 1.55165465, -0.24539113],
#        [-1.44964954,  0.64514119]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# Model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 32    1
# 1     0
# 96    0
# 80    0
# 7     0
# 86    0
# 75    0
# 27    1
# 55    1
# 88    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
