# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  2.081716  1.426554 -2.850986 -0.434887 -2.448912       0
# 1  2.744339  2.157649 -0.794469 -1.338647 -1.562393       0
# 2 -1.729127 -1.158394  2.826466  1.680090  1.390765       1
# 3  2.185275  1.374977 -1.832844  0.495601 -3.935017       0
# 4  2.507011  0.334845  0.072930 -0.686979 -1.215295       0

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
# function for feature sampling
def sample_features(df,percent):
  cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
  new_df = df[cols]
  new_df['target'] = df['target']
  return new_df

# %%
# function for feature sampling
def sample_features(df,percent):
  cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
  new_df = df[cols]
  new_df['target'] = df['target']
  return new_df

# %%
# function for combined sampling

def combined_sampling(df,row_percent,col_percent):
  new_df = sample_rows(df,row_percent)
  return sample_features(new_df,col_percent)

# %%
import random

# %%
import random
import pandas as pd

# function for row sampling
def sample_rows(df, percent):
    return df.sample(frac=percent, random_state=42)

# function for feature sampling
def sample_features(df, percent):
    cols = random.sample(df.columns.tolist()[:-1], int(percent*(df.shape[1]-1)))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# function for combined sampling
def combined_sampling(df, row_percent, col_percent):
    new_df = sample_rows(df, row_percent)
    return sample_features(new_df, col_percent)

# Example usage
df1 = combined_sampling(df, 0.5, 0.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16372\3512628577.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16372\3512628577.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16372\3512628577.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col4', 'col3', 'target'], dtype='object')
# Index(['col5', 'col3', 'target'], dtype='object')
# Index(['col4', 'col3', 'target'], dtype='object')

# %%
df3
# Out:
#         col4      col3  target
# 83 -0.097271 -4.960751       0
# 53 -0.159942 -0.340697       0
# 70 -0.704712 -1.685691       0
# 45  1.451700  0.201697       1
# 44 -1.678089  1.892028       1
# 39 -3.767940  0.871798       0
# 22 -0.416689  2.017179       1
# 80 -1.517805  0.730718       1
# 10  0.951329 -0.460981       1
# 0  -0.434887 -2.850986       0
# 18 -1.088108  0.129612       0
# 30  1.691275 -0.531598       1
# 73 -0.459509 -1.547808       0
# 33 -0.207073  2.070087       1
# 90  1.235978  0.222800       1
# 4  -0.686979  0.072930       0
# 76 -1.935122 -0.244024       0
# 77 -1.164275 -0.816580       0
# 12 -1.962150  0.745522       0
# 31  1.839889  2.783197       1
# 55  2.301800  1.955222       1
# 88  1.498958  0.751068       1
# 26  0.070399 -0.315649       0
# 42  0.799303  3.478033       1
# 69  1.867669 -1.349071       1
# 15 -2.903268  1.405133       0
# 40 -0.233080  2.270066       1
# 96  0.779161  1.464403       1
# 9  -1.330342 -1.156863       0
# 72 -0.095988  1.099444       1
# 11 -0.453931 -3.707368       0
# 47  0.221031  1.132109       1
# 85 -1.427176 -0.621737       0
# 28  4.684569 -1.238867       1
# 93 -1.837207 -0.589437       0
# 5   0.299420 -1.733784       0
# 66 -0.318056 -2.988966       0
# 65  1.804809 -2.252312       1
# 35 -1.186803  0.513712       0
# 16 -0.365694 -0.274844       0
# 49 -1.167847 -1.330350       0
# 34 -0.114305  0.124502       0
# 7  -1.134547  3.399221       1
# 95  0.124536  0.271545       1
# 27  0.292941 -3.311238       0
# 19  3.943861 -0.091851       1
# 81 -1.132909 -3.793514       0
# 25 -0.732902 -0.979476       0
# 62  2.322939  0.002016       1
# 13 -2.160204  2.887321       0

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[0] <= 0.539\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.3333333333333333, 0.75, 'x[1] <= 0.201\ngini = 0.375\nsamples = 36\nvalue = [27, 9]'),
#  Text(0.41666666666666663, 0.8333333333333333, 'True  '),
#  Text(0.16666666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.5, 0.5833333333333334, 'x[0] <= -1.82\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[1] <= 0.622\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.5, 0.25, 'x[0] <= -0.531\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.6666666666666666, 0.75, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.5833333333333333, 0.8333333333333333, '  False')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.55, 0.9285714285714286, 'x[1] <= 0.166\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.26, 0.7857142857142857, 'x[0] <= -0.464\ngini = 0.366\nsamples = 29\nvalue = [22, 7]'),
#  Text(0.405, 0.8571428571428572, 'True  '),
#  Text(0.08, 0.6428571428571429, 'x[1] <= -1.285\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.04, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.12, 0.5, 'x[1] <= -1.198\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.08, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16, 0.35714285714285715, 'x[0] <= -1.838\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.12, 0.21428571428571427, 'x[0] <= -1.93\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.44, 0.6428571428571429, 'x[1] <= -0.401\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.36, 0.5, 'x[0] <= 0.086\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.32, 0.35714285714285715, 'x[0] <= -0.2\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.28, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.52, 0.5, 'x[0] <= 0.003\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.48, 0.35714285714285715, 'x[1] <= -0.169\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.44, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.52, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.56, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.84, 0.7857142857142857, 'x[0] <= 3.715\ngini = 0.363\nsamples = 21\nvalue = [5, 16]'),
#  Text(0.6950000000000001, 0.8571428571428572, '  False'),
#  Text(0.8, 0.6428571428571429, 'x[0] <= -0.001\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.68, 0.5, 'x[0] <= -0.358\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.64, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.72, 0.35714285714285715, 'x[1] <= 1.738\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.68, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.76, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.92, 0.5, 'x[1] <= 0.748\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.88, 0.35714285714285715, 'x[0] <= 1.282\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.84, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.92, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.96, 0.35714285714285715, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.88, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[0] <= 0.539\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.3333333333333333, 0.75, 'x[1] <= 0.201\ngini = 0.375\nsamples = 36\nvalue = [27, 9]'),
#  Text(0.41666666666666663, 0.8333333333333333, 'True  '),
#  Text(0.16666666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(0.5, 0.5833333333333334, 'x[0] <= -1.82\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[1] <= 0.622\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.5, 0.25, 'x[0] <= -0.531\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.25, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.6666666666666666, 0.75, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.5833333333333333, 0.8333333333333333, '  False')]

# %%
clf1.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([-1.042498,	-0.064323]).reshape(1,2))
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df.sample(14,replace=True)
# Out:
#         col1      col2      col3      col4      col5  target
# 19 -0.097091  2.235182 -0.091851  3.943861 -1.850139       1
# 20 -1.988983 -2.019925 -0.012752  1.187266  0.354254       1
# 21 -1.673568 -1.858757  1.610416  0.235272  0.827526       1
# 65  1.826052 -0.080012 -2.252312  1.804809  1.902160       1
# 17  3.138034  1.324351 -1.722524  0.280704 -3.629780       0
# 78  0.161791 -0.762160  0.726074  1.189814  0.228391       1
# 83  0.478571  1.051699 -4.960751 -0.097271 -1.442438       0
# 89 -2.230425 -3.792682  0.403826 -0.550581 -0.286386       1
# 72 -1.178650 -2.757613  1.099444 -0.095988  0.066295       1
# 99 -0.164130 -0.287492  0.194248  0.509771  2.644501       1
# 33 -1.954478 -2.270748  2.070087 -0.207073 -0.335976       1
# 1   2.744339  2.157649 -0.794469 -1.338647 -1.562393       0
# 75  1.081720 -0.823083 -1.080757  1.395119 -2.148388       0
# 99 -0.164130 -0.287492  0.194248  0.509771  2.644501       1
