# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("customer.csv")

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 17   22  Female     Poor        UG       Yes
# 44   77  Female  Average        UG        No
# 28   48    Male     Poor    School        No
# 40   39    Male     Good    School        No
# 35   74    Male     Poor    School       Yes

# %%
df = df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
# Out:
# ------------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In[9], line 4
#       1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
# ----> 4 df = pd.read_csv("your_dataset.csv")   # replace with your file
#       7 X = df.drop("Price", axis=1)   # all columns except target
#       8 y = df["Price"]                # target column
#
# ...

# %%
X_train
# Out:
# ------------------------------------------------
# NameError      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined
