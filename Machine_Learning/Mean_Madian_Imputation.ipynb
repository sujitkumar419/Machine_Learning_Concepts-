# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
# Out:
#   Cell In[1], line 1
#     df = pd.read_csv(""IPL Matches 2006-2020.csv")
#                                             ^
# SyntaxError: invalid decimal literal
